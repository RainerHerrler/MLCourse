# %% [markdown]
# # Decision Tree with Cancer Dataset

# %% [markdown]
# **Loading the Cancer Dataset**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.model_selection import train_test_split

cancer = datasets.load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, stratify=cancer.target, random_state=42)
print('Loaded {} cancer examples with {} features.'.format(cancer.data.shape[0],cancer.data.shape[1]))
print('Classification categories:', cancer.target_names)

# %% [markdown]
# **Training and Evaluating a decision tree model**

# %%
from sklearn.tree import DecisionTreeClassifier
#DecisionTreeClassifier?

# %%
from sklearn.tree import DecisionTreeClassifier
clf_tree = DecisionTreeClassifier(random_state=0)
clf_tree.fit(X_train, y_train)
print('Accuracy on Training Data: {:3f}'.format(clf_tree.score(X_train,y_train)))
print('Accuracy on Test Data: {:3f}'.format(clf_tree.score(X_test,y_test)))

# %%
print('Depth of the Tree', clf_tree.get_depth())
print('Leaves of the Tree', clf_tree.get_n_leaves())

# %% [markdown]
# **Visualization of the decision tree**

# %%
from sklearn import tree
fig, ax = plt.subplots(figsize=(10, 10))
tree.plot_tree(clf_tree, fontsize=10, rounded=True, filled=True)

# %% [markdown]
# **Interpretation and comparison**<br>
# Observation: We have a clear sign of **Overfitting**<br>
# Comparison: For linear models we got up to 98%. So it performs ok but not as good as other models.

# %% [markdown]
# **Adjusting model parameters to prevent overfitting**

# %%
DecisionTreeClassifier?

# %%
clf_tree = DecisionTreeClassifier(max_depth=4, random_state=0)
clf_tree.fit(X_train, y_train)
print('Accuracy on Training Data: {:3f}'.format(clf_tree.score(X_train,y_train)))
print('Accuracy on Test Data: {:3f}'.format(clf_tree.score(X_test,y_test)))
print('Depth of the Tree', clf_tree.get_depth())
print('Leaves of the Tree', clf_tree.get_n_leaves())

# %% [markdown]
# **Drawing the Tree**

# %%
from sklearn import tree
fig, ax = plt.subplots(figsize=(10, 10))
tree.plot_tree(clf_tree, fontsize=10, rounded=True,  filled=True)
plt.show()

# %%
#!pip install pydotplus
import graphviz
import pydotplus
from sklearn.tree import export_graphviz

dot_data = export_graphviz(clf_tree, class_names=cancer.target_names, feature_names=cancer.feature_names, impurity=True, filled=True)
pydot_graph = pydotplus.graph_from_dot_data(dot_data)
pydot_graph.set_size('"10,10!"')
graphviz.Source(pydot_graph.to_string())

# %%
# Importances sum up to 1
print("Importance of Features\n", clf_tree.feature_importances_)
#print("Features shape\n", clf_tree.feature_importances_.shape)

# %% [markdown]
# **Measuring Importance of Features**

# %%
def plot_feature_importances_cancer(model):
    n_features = cancer.data.shape[1]
    plt.barh(range(n_features),model.feature_importances_, align='center')
    plt.yticks(np.arange(n_features), cancer.feature_names)
    plt.xlabel('Importance of the feature');
    plt.ylabel('Feature')
    
plt.figure(figsize=(10,10))
plot_feature_importances_cancer(clf_tree)
