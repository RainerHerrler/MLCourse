# %% [markdown]
# # Fashion MNIST Exercise
#
# This solution notebook walks through loading the data, exploring examples, and reducing the images with PCA.

# %% [markdown]
# Get the necessary files for the next session from
# <a href="https://www.kaggle.com/datasets/zalando-research/fashionmnist">https://www.kaggle.com/datasets/zalando-research/fashionmnist</a>
#
# Download the Fashion MNIST CSV files before running the notebook.

# %%
import pandas as pd

#read pandas
dataTrain = pd.read_csv('fashion-mnist_train.csv')
dataTest = pd.read_csv('fashion-mnist_test.csv')

#convert to numpy
X_train, y_train = dataTrain.iloc[:, 1:].to_numpy(), dataTrain.iloc[:, 0].to_numpy()
X_test, y_test = dataTest.iloc[:, 1:].to_numpy(), dataTest.iloc[:, 0].to_numpy()

print("Training-data", X_train.shape)
print("Test-data", X_test.shape)

# %%
#Define Classnames
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
class_names

# %% [markdown]
# **Plot some examples**
#
# Show a small grid of sample images so the label names become easier to recognize.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(X_train[i].reshape(28, 28), cmap="binary")
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 0.95)
X_reduced = pca.fit_transform(X_train)

# %%
print(X_reduced.shape)
print(pca.explained_variance_ratio_[:10])

# %% [markdown]
# **Elbow method**
#
# Inspect the explained variance to decide how many PCA components are worth keeping.

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.arange(10),pca.explained_variance_ratio_[:10])

# %%
import mglearn
pca = PCA(n_components=2, whiten=True, random_state=0)
pca.fit(X_train)

X_train_pca = pca.transform(X_train)

print("Traingdata")
mglearn.discrete_scatter(X_train_pca[:200,0],X_train_pca[:200,1],y_train[:200])
plt.show()

# %%
from sklearn.manifold import TSNE
import mglearn

tsne = TSNE(random_state=0)
X_train_tsne = tsne.fit_transform(X_train[:1000])

mglearn.discrete_scatter(X_train_tsne[:,0],X_train_tsne[:,1],y_train[:1000])
print("Done")
