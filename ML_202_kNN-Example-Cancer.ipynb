# %% [markdown]
# # Using a KNN with the Cancer Data

# %% [markdown]
# <b>Loading data and create training/test-Data</b>

# %%
# %matplotlib inline
import sklearn
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
print("Sklearn Version", sklearn.__version__)

# %%
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, random_state=66)
print(X_train.shape)
print(X_test.shape)

# %%
cancer.feature_names

# %% [markdown]
# <b>Using kNN Classifier (3 neightbors) and evaluate</b>

# %%
clf = KNeighborsClassifier(n_neighbors=3)
clf.fit(X_train, y_train)

# %%
print("accuracy on train-set:", clf.score(X_train, y_train))
print("accuracy on test-set :", clf.score(X_test, y_test))

# %% [markdown]
# <b>Showing dependency between accuracy and n (for n$\in [1..10]$)</b>

# %%
training_accuracy = []
test_accuracy = []
# try n_neighbors from 1 to 10
neighbors_settings = range(1, 11)

for neighbors in neighbors_settings:
    # build the model
    clf = KNeighborsClassifier(n_neighbors=neighbors)
    clf.fit(X_train, y_train)
    # record training set accuracy
    training_accuracy.append(clf.score(X_train, y_train))
    # record generalization accuracy
    test_accuracy.append(clf.score(X_test, y_test))
    
figure = plt.figure(figsize=(8,5))
plt.plot(neighbors_settings, training_accuracy, label="training accuracy")
plt.plot(neighbors_settings, test_accuracy, label="test accuracy")
plt.ylabel("Accuracy")
plt.xlabel("n_neighbors")
plt.legend()
plt.show()

# %%
import pandas as pd

import matplotlib as mpl

cancer.target_names
colmap = mpl.colors.ListedColormap(['r', 'g'])
df = pd.DataFrame(X_train, columns=cancer.feature_names)
allplots = pd.plotting.scatter_matrix(df, c=y_train, 
                           figsize=(15, 15), diagonal='hist',
                           marker='o', hist_kwds={'bins': 20}, s=10,
                           alpha=0.5, cmap=colmap)
